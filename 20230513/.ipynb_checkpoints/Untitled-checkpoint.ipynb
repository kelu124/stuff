# %%
import pysrt

# %%
subs = pysrt.open("maps.srt")

text = []
for sub in subs:
    print(sub.text)
    text.append(sub.text)
# Out:
# [Musique]
# bonsoir à toutes et à tous on se
# retrouve pour un nouveau lundi soir
# consacré à la géographie
# particulièrement à la cartographie
# notamment à travers un ouvrage qui
# s'appelle ceci n'est pas un atlas la
# cartographie comme outil de luth avec
# neptis vert qui a qui a dirigé dirigé la
# publication de l'ouvrage et qui a aussi
# participé neptis c'est pas votre
# première ouvrage vous avez déjà
# notamment publié un ouvrage qui portait
# sur la cartographie radicale
# cartographie
# 2021 d'accord et celui-là
# en février si je me trompe pas c'est ça
# et
# je pense que le mieux pour être votre
# ouvrage c'est quand même vous citer à
# l'introduction pour qu'un peu les gens
# voient ce que c'est que la cartographie
# quel est son utilité et qu'elle est
# aussi la possibilité d'utiliser des
# processus de manipulation pour parfois
# faire paraître ou plutôt ne pas faire
# apparaître certaines informations
# donc je vous cite nous nous racontons
# ...

# %%
paper = " ".join(text).replace("luth","lutte").replace("neptis","Nepthys")
with open('maps.txt', 'w') as f:
    f.write(paper)
